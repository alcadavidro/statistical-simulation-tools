# %%
import numpy as np
import pandas as pd

from statistical_simulation_tools import DistributionFitter
from statistical_simulation_tools.utils import *

# %%
data = np.random.normal(loc=10.0, scale=2.0, size=(10000,))

# %%
fitter = DistributionFitter(distributions=get_common_distributions(), bins=sturges_bins(data))
fitter.fit(data)

# %%
fitter.summary()
# Out:
#          distribution  ...                                      fitted_params
# norm             norm  ...  {'loc': 9.997465910941735, 'scale': 2.01047334...
# lognorm       lognorm  ...  {'s': 1.91732200114877e-06, 'loc': -1048574.11...
# gamma           gamma  ...  {'a': 6997.23378549699, 'loc': -158.2393172386...
# chi2             chi2  ...  {'df': 343.2987075022196, 'loc': -16.606264783...
# exponpow     exponpow  ...  {'b': 2.950706646287804, 'loc': 1.865758011679...
# cauchy         cauchy  ...  {'loc': 10.012572278366635, 'scale': 1.2326486...
# rayleigh     rayleigh  ...  {'loc': 1.8792074293871317, 'scale': 5.9138872...
# powerlaw     powerlaw  ...  {'a': 1.3478041548362552, 'loc': 1.87924016751...
# uniform       uniform  ...  {'loc': 1.880216466672655, 'scale': 16.4579067...
# expon           expon  ...  {'loc': 1.880216466672655, 'scale': 8.11724944...
#
# [10 rows x 8 columns]
