# %%
import logging

import numpy as np
import pandas as pd

from statistical_simulation_tools import DistributionFitter
from statistical_simulation_tools.utils import *

# %%
logging.basicConfig(level=logging.DEBUG)

# %%
data = np.random.normal(loc=10.0, scale=2.0, size=(10000,))

# %%
fitter = DistributionFitter(
    distributions=get_common_distributions(), 
    bins=sturges_bins(data)
)
fitter.fit(data)
# Out:
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: cauchy
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: chi2
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: expon
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: exponpow
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: gamma
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: lognorm
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: norm
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: powerlaw
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: rayleigh
# DEBUG:statistical_simulation_tools.distribution_fitter:Fitting distribution: uniform

# %%
fitter.summary(sort_by="ks_statistic")
# Out:
#          distribution  squared_error         aic         bic  ks_statistic  \
# gamma           gamma       0.003438  804.746806  826.377827      0.004711
# lognorm       lognorm       0.003438  804.783580  826.414601      0.004745
# norm             norm       0.003438  802.783992  817.204672      0.004753
# chi2             chi2       0.005712  811.319479  832.950500      0.019016
# exponpow     exponpow       0.045451  957.963875  979.594897      0.057986
# cauchy         cauchy       0.079533  696.733179  711.153859      0.074244
# uniform       uniform       0.503281  546.237482  560.658163      0.237394
# rayleigh     rayleigh       0.276703  592.504450  606.925130      0.243108
# powerlaw     powerlaw       0.492646  558.454599  580.085620      0.324797
# expon           expon       0.705118  607.608273  622.028954      0.386532
#
#             ks_p_value                                      fitted_params
# gamma     9.787545e-01  {'a': 2703322.8339525573, 'loc': -3257.8907562...
# lognorm   9.772081e-01  {'s': 6.063875017381557e-05, 'loc': -32765.502...
# norm      9.768131e-01  {'loc': 10.010027797737274, 'scale': 1.9874660...
# chi2      1.427534e-03  {'df': 228.7563522333386, 'loc': -11.454599320...
# exponpow  1.142865e-29  {'b': 2.784257915489711, 'loc': 2.483793693970...
# cauchy    2.204410e-48  {'loc': 10.008316100061474, 'scale': 1.2234137...
# uniform   0.000000e+00  {'loc': 2.497788481345789, 'scale': 15.0471320...
# rayleigh  0.000000e+00  {'loc': 2.496806324245588, 'scale': 5.49538524...
# powerlaw  0.000000e+00  {'a': 1.3595402352684176, 'loc': 2.49682980539...
# expon     0.000000e+00  {'loc': 2.497788481345789, 'scale': 7.51223931...
