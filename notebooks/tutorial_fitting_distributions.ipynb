# %%
import logging

import numpy as np
import pandas as pd

from statistical_simulation_tools import DistributionFitter
from statistical_simulation_tools.utils import *

# %%
logging.basicConfig(filename='example.log', encoding='utf-8', level=logging.DEBUG)

# %%
data = np.random.normal(loc=10.0, scale=2.0, size=(10000,))

# %%
fitter = DistributionFitter(distributions=get_common_distributions(), bins=sturges_bins(data))
fitter.fit(data)

# %%
fitter.summary()
# Out:
#          distribution  squared_error          aic          bic  ks_statistic  \
# lognorm       lognorm       0.004084   808.742427   830.373448      0.005390
# gamma           gamma       0.004084   808.767210   830.398231      0.005396
# norm             norm       0.004120   808.747417   823.168098      0.006402
# chi2             chi2       0.006385   798.754762   820.385783      0.021116
# exponpow     exponpow       0.045803  1069.403873  1091.034894      0.059289
# cauchy         cauchy       0.072003   699.592582   714.013263      0.074074
# rayleigh     rayleigh       0.243142   601.361072   615.781753      0.223907
# powerlaw     powerlaw       0.493756   554.249349   575.880370      0.328108
# uniform       uniform       0.498583   547.382219   561.802900      0.265485
# expon           expon       0.681165   609.185144   623.605825      0.371366
#
#             ks_p_value                                      fitted_params
# ...
